# %%
import numpy as np
import pandas as pd

# %%
x=pd.read_csv(r"D:\work\cleaned_all_phones.csv")

# %%
x
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0           Li-Po        2        2016-09-01      140.0  ...        False
# 1          Li-Ion        2        2016-12-01      140.0  ...         True
# 2          Li-Ion        4        2017-01-01      147.0  ...         True
# 3           Li-Po        4        2017-01-01      165.0  ...         True
# 4          Li-Ion        4        2017-02-01      145.0  ...         True
# ...           ...      ...               ...        ...  ...          ...
# 1507        Li-Po        8        2023-08-18      190.0  ...         True
# 1508        Li-Po        8        2023-08-23      190.0  ...         True
# 1509        Li-Po       16        2023-08-28      205.0  ...         True
# 1510        Li-Po       24        2023-08-28      205.0  ...         True
# 1511        Li-Po        8        2023-08-31      175.0  ...         True
#
#       video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# 0        False     False         True        False         False
# 1        False     False         True        False         False
# 2        False     False         True        False         False
# 3        False     False         True        False          True
# 4         True     False         True         True         False
# ...        ...       ...          ...          ...           ...
# 1507     False     False         True        False         False
# 1508     False     False         True        False         False
# 1509      True     False        False         True         False
# 1510      True     False        False         True         False
# 1511      True     False         True        False         False
#
#       video_240fps  video_480fps  video_960fps  price(USD)
# 0            False         False         False     120.000
# 1            False         False         False     100.000
# 2            False         False         False     420.000
# 3            False         False         False     150.000
# 4            False         False         False     420.000
# ...            ...           ...           ...         ...
# 1507         False         False         False     170.000
# 1508         False         False         False     182.880
# 1509         False         False         False     380.000
# 1510         False         False         False     470.000
# 1511         False         False         False     287.988
#
# [1512 rows x 22 columns]

# %% [markdown]
# # 1. How many unique  mobile brands are there in the data provided

# %%
x["brand"].unique()
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %%
x["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %% [markdown]
# # 2.What is the average ram size of all the collected data

# %%
x["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %% [markdown]
# # 3.Which phone is having the maximum and minimum battery capacity

# %%
x["battery"].max()
# Out:
# 7250

# %%
x.loc[x["battery"]==7250]
# Out:
#     phone_name  brand          os  inches resolution  battery battery_type  \
# 573         V6  Honor  Android 10    10.4  1200x2000     7250        Li-Po
#
#      ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 573        8        2020-05-19      480.0  ...         True     False
#
#      video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 573     False         True        False         False         False
#
#      video_480fps  video_960fps  price(USD)
# 573         False         False       280.0
#
# [1 rows x 22 columns]

# %%
x["battery"].min()
# Out:
# 1821

# %%
x.loc[x["battery"]==1821]
# Out:
#            phone_name  brand      os  inches resolution  battery battery_type  \
# 62           iPhone 8  Apple  iOS 11     4.7   750x1334     1821       Li-Ion
# 536  iPhone SE (2020)  Apple  iOS 13     4.7   750x1334     1821       Li-Ion
#
#      ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 62         2        2017-09-12      148.0  ...         True      True
# 536        3        2020-04-15      148.0  ...         True      True
#
#      video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 62      False         True         True          True          True
# 536     False         True         True          True          True
#
#      video_480fps  video_960fps  price(USD)
# 62          False         False       210.0
# 536         False         False       189.5
#
# [2 rows x 22 columns]

# %% [markdown]
# # 4. What is the maximum battery capacity provided by Huawei Company

# %%
x1=x.loc[(x["brand"]=="Huawei")]

# %%
x1
# Out:
#           phone_name   brand           os  inches resolution  battery  \
# 0       Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 2     P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 4                P10  Huawei  Android 7.0    5.10  1080x1920     3200
# 6           P10 Lite  Huawei  Android 7.0    5.20  1080x1920     3000
# 7           P10 Plus  Huawei  Android 7.0    5.50  1440x2560     3750
# ...              ...     ...          ...     ...        ...      ...
# 1296      nova 10 SE  Huawei      EMUI 12    6.67  1080x2400     4500
# 1312        nova Y61  Huawei      EMUI 12    6.52   720x1600     5000
# 1430        nova 11i  Huawei      EMUI 13    6.80  1080x2388     5000
# 1433        nova Y71  Huawei      EMUI 12    6.75   720x1600     6000
# 1448        nova Y91  Huawei      EMUI 13    6.95  1080x2376     7000
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0           Li-Po        2        2016-09-01      140.0  ...        False
# 2          Li-Ion        4        2017-01-01      147.0  ...         True
# 4          Li-Ion        4        2017-02-01      145.0  ...         True
# 6           Li-Po        4        2017-02-01      146.0  ...         True
# 7          Li-Ion        6        2017-02-01      165.0  ...         True
# ...           ...      ...               ...        ...  ...          ...
# 1296        Li-Po        8        2022-10-05      184.0  ...         True
# 1312        Li-Po        6        2022-11-01      188.0  ...         True
# 1430        Li-Po        8        2023-05-01      193.0  ...         True
# 1433        Li-Po        8        2023-05-09      199.0  ...         True
# 1448        Li-Po        8        2023-05-23      214.0  ...         True
#
#       video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# 0        False     False         True        False         False
# 2        False     False         True        False         False
# 4         True     False         True         True         False
# 6        False     False         True        False         False
# 7         True     False         True         True         False
# ...        ...       ...          ...          ...           ...
# 1296     False     False         True        False         False
# 1312     False     False         True        False         False
# 1430     False     False         True        False         False
# 1433     False     False         True        False         False
# 1448     False     False         True        False         False
#
#       video_240fps  video_480fps  video_960fps  price(USD)
# 0            False         False         False      120.00
# 2            False         False         False      420.00
# 4            False         False         False      420.00
# 6            False         False         False      420.00
# 7            False         False         False      170.00
# ...            ...           ...           ...         ...
# 1296         False         False         False      311.87
# 1312         False         False         False      189.30
# 1430         False         False         False      279.00
# 1433         False         False         False      190.00
# 1448         False         False         False      280.00
#
# [137 rows x 22 columns]

# %%
x1["battery"].max()
# Out:
# 7000

# %%
x1.loc[x1["battery"]==7000]
# Out:
#      phone_name   brand       os  inches resolution  battery battery_type  \
# 1448   nova Y91  Huawei  EMUI 13    6.95  1080x2376     7000        Li-Po
#
#       ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 1448        8        2023-05-23      214.0  ...         True     False
#
#       video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 1448     False         True        False         False         False
#
#       video_480fps  video_960fps  price(USD)
# 1448         False         False       280.0
#
# [1 rows x 22 columns]

# %% [markdown]
# # 5. Which Phone brand is providing the highest and lowest ram

# %%
x.loc[x["ram(GB)"].max(),["brand"]]
# Out:
# brand    Huawei
# Name: 24, dtype: object

# %% [markdown]
# # 6. How many phones has android 7.0 as there operating system

# %%
x["os"].value_counts()
# Out:
# Android 11                322
# Android 10                317
# Android 12                233
# Android 9.0               210
# Android 13                154
# Android 8.1                83
# Android 8.0                55
# Android 7.0                33
# Android 7.1.1              17
# Android 7.1                14
# Android 7.1.2              13
# EMUI 12                     6
# Android 6.0                 6
# Android 8.1 Oreo            5
# iOS 16                      4
# iOS 15                      4
# iOS 14.1                    4
# iOS 13                      4
# iOS 12                      3
# Android 6                   3
# Android                     3
# Android 12 or 13            2
# Android 5.1                 2
# Android 9.0 Pie             2
# Android 8.0 Oreo            2
# Android 6.0.1               2
# EMUI 13                     2
# Android 10/ Android 11      1
# iOS 15.4                    1
# iOS 11.1.1                  1
# iOS 11                      1
# Android 12L                 1
# Tizen 3.0                   1
# Android 7.0.1               1
# Name: os, dtype: int64

# %% [markdown]
# # 7. Which Phone is the oldest

# %%
x["announcement_date"]
# Out:
# 0       2016-09-01
# 1       2016-12-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-02-01
#            ...
# 1507    2023-08-18
# 1508    2023-08-23
# 1509    2023-08-28
# 1510    2023-08-28
# 1511    2023-08-31
# Name: announcement_date, Length: 1512, dtype: object

# %%
x["announcement_date"].min()
# Out:
# '2016-09-01'

# %%
x.loc[x["announcement_date"]=="2016-09-01"]
# Out:
#      phone_name   brand           os  inches resolution  battery battery_type  \
# 0  Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200        Li-Po
#
#    ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  video_8K  \
# 0        2        2016-09-01      140.0  ...        False     False     False
#
#    video_30fps  video_60fps  video_120fps  video_240fps  video_480fps  \
# 0         True        False         False         False         False
#
#    video_960fps  price(USD)
# 0         False       120.0
#
# [1 rows x 22 columns]

# %% [markdown]
# # 8. Which brand produced maximum number of phone in the given data

# %%
x["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %% [markdown]
# # 9.Give the count of phones supporting 1)4k video 2)8k video 3)2k video

# %%
x["video_4K"].sum()
# Out:
# 801

# %%
x["video_8K"].sum()
# Out:
# 86

# %% [markdown]
# # 10. How many phones supports Li-Po and Li-ion Battery

# %%
x["battery_type"].value_counts()
# Out:
# Li-Po     1242
# Li-Ion     270
# Name: battery_type, dtype: int64

# %% [markdown]
# # 11.How many sony phones supports 720x1280 resolution

# %%
x2=x.loc[x["brand"]=="Sony"]

# %%
x2
# Out:
#               phone_name brand             os  inches resolution  battery  \
# 5             Xperia XA1  Sony    Android 7.0    5.00   720x1280     2300
# 8       Xperia XA1 Ultra  Sony    Android 7.0    6.00  1080x1920     2700
# 11            Xperia XZs  Sony    Android 7.1    5.20  1080x1920     2900
# 12     Xperia XZ Premium  Sony    Android 7.1    5.46  3840x2160     3230
# 13             Xperia L1  Sony    Android 7.0    5.50   720x1280     2620
# 48    Xperia XZ1 Compact  Sony    Android 8.0    4.60   720x1280     2700
# 50       Xperia XA1 Plus  Sony    Android 7.0    5.50  1080x1920     3430
# 54            Xperia XZ1  Sony    Android 8.0    5.20  1080x1920     2700
# 66      Xperia R1 (Plus)  Sony    Android 7.1    5.20   720x1280     2620
# 87      Xperia XA2 Ultra  Sony    Android 8.0    6.00  1080x1920     3580
# 89            Xperia XA2  Sony    Android 8.0    5.20  1080x1920     3300
# 93             Xperia L2  Sony  Android 7.1.1    5.50   720x1280     3300
# 94    Xperia XZ2 Compact  Sony    Android 8.0    5.00  1080x2160     2870
# 103           Xperia XZ2  Sony    Android 8.0    5.70  1080x2160     3180
# 125   Xperia XZ2 Premium  Sony    Android 8.0    5.80  3840x2160     3540
# 170      Xperia XA2 Plus  Sony    Android 8.0    6.00  1080x2160     3580
# 190           Xperia XZ3  Sony    Android 9.0    6.00  1440x2880     3300
# 257            Xperia L3  Sony    Android 8.0    5.70   720x1440     3300
# 271             Xperia 1  Sony    Android 9.0    6.50  1644x3840     3330
# 273       Xperia 10 Plus  Sony    Android 9.0    6.50  1080x2520     3000
# 274            Xperia 10  Sony    Android 9.0    6.00  1080x2520     2870
# 396             Xperia 5  Sony    Android 9.0    6.10  1080x2520     3140
# 482            Xperia L4  Sony    Android 9.0    6.20   720x1680     3580
# 483          Xperia 1 II  Sony     Android 10    6.50  1644x3840     4000
# 484         Xperia 10 II  Sony     Android 10    6.00  1080x2520     3600
# 487           Xperia Pro  Sony     Android 10    6.50  1644x3840     4000
# 664          Xperia 5 II  Sony     Android 10    6.10  1080x2520     4000
# 833         Xperia 1 III  Sony     Android 11    6.50  1644x3840     4500
# 834         Xperia 5 III  Sony     Android 11    6.10  1080x2520     4500
# 836        Xperia 10 III  Sony     Android 11    6.00  1080x2520     4500
# 933   Xperia 10 III Lite  Sony     Android 11    6.00  1080x2520     4500
# 990         Xperia Pro-I  Sony     Android 11    6.50  1644x3840     4500
# 1176         Xperia 1 IV  Sony     Android 12    6.50  1644x3840     5000
# 1178        Xperia 10 IV  Sony     Android 12    6.00  1080x2520     5000
# 1267         Xperia 5 IV  Sony     Android 12    6.10  1080x2520     5000
# 1441          Xperia 1 V  Sony     Android 13    6.50  1644x3840     5000
# 1442         Xperia 10 V  Sony     Android 13    6.10  1080x2520     5000
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 5          Li-Ion        3        2017-02-01      143.0  ...         True
# 8          Li-Ion        4        2017-02-01      188.0  ...         True
# 11         Li-Ion        4        2017-02-27      161.0  ...         True
# 12         Li-Ion        4        2017-02-27      195.0  ...         True
# 13         Li-Ion        2        2017-03-01      180.0  ...         True
# 48         Li-Ion        4        2017-08-01      140.0  ...         True
# 50         Li-Ion        4        2017-08-01      189.0  ...         True
# 54         Li-Ion        4        2017-08-31      155.0  ...         True
# 66         Li-Ion        3        2017-10-01      154.0  ...         True
# 87         Li-Ion        4        2018-01-01      221.0  ...         True
# 89         Li-Ion        3        2018-01-01      171.0  ...         True
# 93         Li-Ion        3        2018-01-01      178.0  ...         True
# 94         Li-Ion        4        2018-02-01      168.0  ...         True
# 103        Li-Ion        6        2018-02-26      198.0  ...         True
# 125        Li-Ion        6        2018-04-01      236.0  ...         True
# 170        Li-Ion        6        2018-07-01      205.0  ...         True
# 190        Li-Ion        6        2018-08-30      193.0  ...         True
# 257        Li-Ion        3        2019-02-01      156.0  ...         True
# 271        Li-Ion        6        2019-02-25      178.0  ...         True
# 273        Li-Ion        6        2019-02-25      180.0  ...         True
# 274        Li-Ion        4        2019-02-25      162.0  ...         True
# 396        Li-Ion        6        2019-09-05      164.0  ...         True
# 482        Li-Ion        3        2020-02-20      178.0  ...         True
# 483         Li-Po        8        2020-02-24      181.0  ...         True
# 484         Li-Po        4        2020-02-24      151.0  ...         True
# 487         Li-Po       12        2020-02-24      225.0  ...         True
# 664        Li-Ion        8        2020-09-17      163.0  ...         True
# 833         Li-Po       12        2021-04-14      186.0  ...         True
# 834         Li-Po        8        2021-04-14      168.0  ...         True
# 836         Li-Po        6        2021-04-14      169.0  ...         True
# 933         Li-Po        6        2021-08-20      169.0  ...         True
# 990         Li-Po       12        2021-10-26      211.0  ...         True
# 1176        Li-Po       12        2022-05-11      185.0  ...         True
# 1178        Li-Po        6        2022-05-11      161.0  ...         True
# 1267        Li-Po        8        2022-09-01      172.0  ...         True
# 1441        Li-Po       12        2023-05-11      187.0  ...         True
# 1442        Li-Po        8        2023-05-11      159.0  ...         True
#
#       video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# 5        False     False         True        False         False
# 8        False     False         True        False         False
# 11        True     False         True         True         False
# 12        True     False         True         True         False
# 13       False     False         True        False         False
# 48        True     False         True         True         False
# 50       False     False         True        False         False
# 54        True     False         True         True         False
# 66       False     False         True        False         False
# 87        True     False         True        False         False
# 89        True     False         True        False         False
# 93       False     False         True        False         False
# 94        True     False         True         True         False
# 103       True     False         True         True         False
# 125       True     False         True         True         False
# 170       True     False         True        False         False
# 190       True     False         True         True         False
# 257      False     False         True        False         False
# 271       True     False         True         True         False
# 273       True     False         True        False         False
# 274       True     False         True        False         False
# 396       True     False         True         True         False
# 482      False     False         True        False         False
# 483       True     False        False        False          True
# 484       True     False         True        False         False
# 487       True     False        False         True          True
# 664       True     False        False        False          True
# 833       True     False        False        False          True
# 834       True     False        False        False          True
# 836       True     False         True        False         False
# 933       True     False         True        False         False
# 990       True     False        False        False          True
# 1176      True     False        False        False          True
# 1178     False     False         True        False         False
# 1267      True     False        False        False          True
# 1441      True     False        False        False          True
# 1442     False     False         True        False         False
#
#       video_240fps  video_480fps  video_960fps  price(USD)
# 5            False         False         False      140.00
# 8            False         False         False      250.00
# 11           False         False          True      220.00
# 12           False         False          True      320.00
# 13           False         False         False      110.00
# 48           False         False          True      300.00
# 50           False         False         False      150.00
# 54           False         False          True      260.00
# 66           False         False         False      168.00
# 87           False         False         False      260.00
# 89           False         False         False      200.00
# 93           False         False         False      140.00
# 94           False         False          True      430.00
# 103          False         False          True      360.00
# 125          False         False          True      460.00
# 170          False         False         False      240.00
# 190          False         False          True      510.00
# 257          False         False         False      230.00
# 271          False         False          True      500.00
# 273          False         False         False      560.00
# 274          False         False         False      280.00
# 396          False         False         False      500.00
# 482          False         False         False      200.00
# 483          False         False         False      700.00
# 484          False         False         False      700.00
# 487          False         False         False     2000.00
# 664          False         False         False      650.00
# 833          False         False         False      495.00
# 834          False         False         False      589.99
# 836          False         False         False      746.00
# 933          False         False         False      370.00
# 990          False         False         False      998.00
# 1176         False         False         False      889.99
# 1178         False         False         False      329.99
# 1267         False         False         False      704.99
# 1441         False         False         False     1079.00
# 1442         False         False         False      378.00
#
# [37 rows x 22 columns]

# %%
x2.loc[x2["resolution"]=="720x1280"]
# Out:
#             phone_name brand             os  inches resolution  battery  \
# 5           Xperia XA1  Sony    Android 7.0     5.0   720x1280     2300
# 13           Xperia L1  Sony    Android 7.0     5.5   720x1280     2620
# 48  Xperia XZ1 Compact  Sony    Android 8.0     4.6   720x1280     2700
# 66    Xperia R1 (Plus)  Sony    Android 7.1     5.2   720x1280     2620
# 93           Xperia L2  Sony  Android 7.1.1     5.5   720x1280     3300
#
#    battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 5        Li-Ion        3        2017-02-01      143.0  ...         True
# 13       Li-Ion        2        2017-03-01      180.0  ...         True
# 48       Li-Ion        4        2017-08-01      140.0  ...         True
# 66       Li-Ion        3        2017-10-01      154.0  ...         True
# 93       Li-Ion        3        2018-01-01      178.0  ...         True
#
#     video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 5      False     False         True        False         False         False
# 13     False     False         True        False         False         False
# 48      True     False         True         True         False         False
# 66     False     False         True        False         False         False
# 93     False     False         True        False         False         False
#
#     video_480fps  video_960fps  price(USD)
# 5          False         False       140.0
# 13         False         False       110.0
# 48         False          True       300.0
# 66         False         False       168.0
# 93         False         False       140.0
#
# [5 rows x 22 columns]
