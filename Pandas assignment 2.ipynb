# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv(r"D:\work\imdb_anime.csv")

# %%
x
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
x["Title"].unique
# Out:
# <bound method Series.unique of 0                                          One Piece
# 1        Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                        The Super Mario Bros. Movie
# 3                                    Attack on Titan
# 4                                     Jujutsu Kaisen
#                             ...
# 45712                 Demon Slayer: Kimetsu no Yaiba
# 45713                 Demon Slayer: Kimetsu no Yaiba
# 45714                                      One Piece
# 45715                                  Marmalade Boy
# 45716                                Cinderella Nine
# Name: Title, Length: 45717, dtype: object>

# %% [markdown]
# # 1. How many unique animes are there?

# %%
x["Title"].value_counts()
# Out:
# Doraemon                                             2758
# Sazae-san                                            2397
# Detective Conan                                      1005
# Pokémon                                               990
# One Piece                                             905
#                                                      ...
# Outburst Dreamer Boys                                   1
# Shoot! Goal to the Future                               1
# 2112: The Birth of Doraemon                             1
# Ghost Sweeper Mikami: The Great Paradise Battle!!       1
# JoJo's Bizarre Adventure: Golden Wind                   1
# Name: Title, Length: 9851, dtype: int64

# %% [markdown]
# # 2. Which anime has highest rating?

# %%
x["User Rating"].value_counts()
# Out:
# 7.6            1270
# 7.5            1174
# 7.4            1171
# 7.2            1144
# 7.7            1142
#                ...
# 1.7               2
# 1.8               2
# 2.1               2
# 2.5               1
# User Rating       1
# Name: User Rating, Length: 87, dtype: int64

# %%
x.replace({"User Rating":{"User Rating":0}},inplace=True)

# %%
x1=x.astype({"User Rating":float})

# %%
x1
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure          8.9         187,689  24 min
# 1      Animation, Action, Adventure          7.4          28,895  99 min
# 2      Animation, Adventure, Comedy          7.1         189,108  92 min
# ...

# %%
x1["User Rating"].max()
# Out:
# 9.9

# %%
x1.loc[x1["User Rating"]==9.9]
# Out:
#                                Title                         Genre  \
# 13656                    Idaten Jump  Animation, Adventure, Comedy
# 17874                   Vinland Saga  Animation, Action, Adventure
# 22753                Attack on Titan  Animation, Action, Adventure
# 34677                Hunter x Hunter  Animation, Action, Adventure
# 39614  Legend of the Galactic Heroes      Animation, Action, Drama
# 45689                Attack on Titan  Animation, Action, Adventure
#
#        User Rating Number of Votes Runtime         Year  \
# 13656          9.9              11  20 min  (2005–2006)
# 17874          9.9          13,663  24 min     (2019– )
# 22753          9.9          86,907  24 min  (2013–2023)
# 34677          9.9           9,012  23 min  (2011–2014)
# 39614          9.9             350  32 min  (1988–1997)
# 45689          9.9         109,163  24 min  (2013–2023)
#
#                                                  Summary  \
# ...

# %% [markdown]
# # 3. Which animes are having the ratings b/w 7 and 9?

# %%
x1.loc[x1["User Rating"]>7 & (x1["User Rating"]<9)]
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45711               Demon Slayer: Kimetsu no Yaiba
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure          8.9         187,689  24 min
# 1      Animation, Action, Adventure          7.4          28,895  99 min
# 2      Animation, Adventure, Comedy          7.1         189,108  92 min
# ...

# %% [markdown]
# # 4.  Which anime has the highest and lowest runtime?

# %%
x1["Runtime"]=x1["Runtime"].str.replace(" min","")

# %%
x1["Runtime"]
# Out:
# 0         24
# 1         99
# 2         92
# 3         24
# 4         24
#         ...
# 45712     24
# 45713     24
# 45714    NaN
# 45715     24
# 45716     24
# Name: Runtime, Length: 45717, dtype: object

# %%
x1=x1.astype({"Runtime":float})

# %%
x1.replace({"Runtime":{"Runtime":0}},inplace=True)

# %%
x1["Runtime"]=x1["Runtime"].str.replace(",","")

# %%
x1.loc[x1["Runtime"].max()]
# Out:
# Title                                                      Charlotte
# Genre                                       Animation, Drama, Family
# User Rating                                                      7.5
# Number of Votes                                                7,486
# Runtime                                                         24.0
# Year                                                     (2015–2016)
# Summary            The story takes place in an alternate reality ...
# Stars              Kôki Uchiyama,Ayane Sakura,Momo Asakura,Takahi...
# Certificate                                                    TV-PG
# Metascore                                                        NaN
# Gross                                                           7486
# Episode                                                            0
# Episode Title                                                    NaN
# Name: 1271, dtype: object

# %%
x1.loc[x1["Runtime"].min()]
# Out:
# Title                    Teenage Mutant Ninja Turtles: Mutant Mayhem
# Genre                                   Animation, Action, Adventure
# User Rating                                                      7.4
# Number of Votes                                               28,895
# Runtime                                                         99.0
# Year                                                          (2023)
# Summary            The film follows the Turtle brothers as they w...
# Stars                                                            NaN
# Certificate                                                       PG
# Metascore                                                 74
# Gross                                                          28895
# Episode                                                            0
# Episode Title                                                    NaN
# Name: 1, dtype: object

# %% [markdown]
# # 5. What is the runtime difference between one Piece and the super mario bros movie?

# %%
x1.loc[x1["Title"]=="One Piece",["Runtime"]]
# Out:
#        Runtime
# 0         24.0
# 841       24.0
# 13549     24.0
# 13550     25.0
# 13551     24.0
# ...        ...
# 45359      NaN
# 45373      NaN
# 45584      NaN
# 45649      NaN
# 45714      NaN
#
# [905 rows x 1 columns]

# %%
x1.loc[x1["Title"]=="The Super Mario Bros. Movie",["Runtime"]]
# Out:
#      Runtime
# 2       92.0
# 843     92.0

# %%
x1=x1.astype({"Genre":str})

# %%
x1["Genre"].str.find("Action")
# Out:
# 0        11
# 1        11
# 2        -1
# 3        11
# 4        11
#          ..
# 45712    11
# 45713    11
# 45714    11
# 45715    -1
# 45716    -1
# Name: Genre, Length: 45717, dtype: int64

# %% [markdown]
# # 9. Which anime has highest gross?

# %%
x1["Gross"]=x1["Gross"].str.replace("Gross","0")

# %%
x1=x1.astype({"Gross":float})

# %%
x1.loc[x1["Gross"]==1162284]
# Out:
#       Title                         Genre  User Rating Number of Votes  \
# 47   WALL·E  Animation, Adventure, Family          8.4       1,162,284
# 888  WALL·E  Animation, Adventure, Family          8.4       1,162,284
#
#      Runtime    Year                                            Summary Stars  \
# 47      98.0  (2008)  In the distant future, a small waste-collectin...   NaN
# 888     98.0  (2008)  In the distant future, a small waste-collectin...   NaN
#
#     Certificate   Metascore      Gross Episode Episode Title
# 47            G  95          1162284.0       0           NaN
# 888           G  95          1162284.0       0           NaN

# %% [markdown]
# # 10. Which anime has least gross?

# %%
x1.loc[x1["Gross"].min()]
# Out:
# Title                                                      One Piece
# Genre                                   Animation, Action, Adventure
# User Rating                                                      8.9
# Number of Votes                                              187,689
# Runtime                                                         24.0
# Year                                                        (1999– )
# Summary            Follows the adventures of Monkey D. Luffy and ...
# Stars              Mayumi Tanaka,Laurent Vernin,Akemi Okamura,Ton...
# Certificate                                                    TV-14
# Metascore                                                        NaN
# Gross                                                       187689.0
# Episode                                                            0
# Episode Title                                                    NaN
# Name: 0, dtype: object

# %% [markdown]
# # 11. How many animes belongs to PG certificate?

# %%
x1.loc[x1["Certificate"]=="PG"]
# Out:
#                                              Title  \
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 7                     Puss in Boots: The Last Wish
# 11                                        Coraline
# 17                                          Sing 2
# ...                                            ...
# 41231                         You're Under Arrest!
# 41232                         You're Under Arrest!
# 41233                         You're Under Arrest!
# 41234                         You're Under Arrest!
# 41235                         You're Under Arrest!
#
#                               Genre  User Rating Number of Votes  Runtime  \
# 1      Animation, Action, Adventure          7.4          28,895     99.0
# 2      Animation, Adventure, Comedy          7.1         189,108     92.0
# 7      Animation, Adventure, Comedy          7.8         153,495    102.0
# ...

# %% [markdown]
# # 12. What is the avg number of votes?

# %%
x1["Number of Votes"]=x1["Number of Votes"].str.replace(",","")

# %%
x1.replace({"Number of Votes":{"Number of Votes":0}},inplace=True)

# %%
x1=x1.astype({"Number of Votes":float})

# %%
x1["Number of Votes"].mean()
# Out:
# 2983.6828341796954
